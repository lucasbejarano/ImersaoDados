# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasbejarano/ImersaoDados/blob/main/Alura_aula04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Semana imersão dados da Alura
#
# * por: Lucas Bejarano
# * linkedin: https://www.linkedin.com/in/lucas-bejarano/
# * github: https://github.com/lucasbejarano/

# %%
import pandas as pd
url = "https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true"
dados = pd.read_csv(url, compression= 'zip')

dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
#Cantidad de linhas e colunas
dados.shape
# Out:
# (23814, 877)

# %%
#coluna especifica do dataset
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
#valores da columna tratamento
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
###Desafio 01

controle = dados.query('tratamento == "com_controle"')
controle.droga.unique()
# Out:
# array(['cacb2b860'], dtype=object)

# %%
###Desafio 02

dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %%
###Desafio 03

dados['tratamento'].value_counts(normalize=True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
###Desafio 04
dados['droga'].nunique()

#len(dados['droga'].unique())
# Out:
# 3289

# %%
###Desafio 05: Procurar na documentacao o metodo query(pandas).

dados.query('tratamento == "com_droga" ').head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
#Desafio 06: Renomear as colunas tirando o hifen

dados.columns = dados.columns.str.replace("[-]", "")

# %%
dados['dose'].value_counts(normalize=True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
dados['dose'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.bar()

# %%
#valores g-0 maiores do que 0 - dataset antigo

#dados_filtrados = dados[dados['g-0'] > 0]

#dados_filtrados.head()

#outro jeito: Desafio 5

dados.query('g0 > 0')
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6      id_001bd861f     com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23807  id_fff7e6992     com_droga     48   D1  ...  0.3738  0.8636  0.4494  0.1218
# 23808  id_fff8c2444     com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
#Solução para uma dúvida em Discord - desafio 07
import matplotlib.pyplot as plt

fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.set_title("Gráfico de barras para tratamentos", fontweight="bold", color="#2874A6",fontsize=20)
ax.set_xlabel("Tratamento", fontweight="bold", fontsize="large", color="#566573")
ax.set_ylabel("Quantidade", fontweight="bold", color = "#566573", fontsize="large")


dados_trat = dados['tratamento'].value_counts()

a = dados_trat.loc['com_droga']
b = dados_trat.loc['com_controle']

ax.bar("com droga",a, label="Com droga", color="green")
ax.bar("com controle", b, label="Com controle", color="red") 

plt.legend()

# %%
#Desafio 07: Deixar os graficos bonitoes. (Matplotlib).

fig,ax= plt.subplots()
fig.patch.set_facecolor("#CBCDCB")


labels=['Com droga','Com tratamento']
colors=['#C44B4F','#607D86']
ax.pie(dados['tratamento'].value_counts(),labels=labels,explode=[0,0.3], colors=colors,autopct='%1.1f%%')
ax.set_title("Tratamentos",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Tratamentos')

# %%
#Desafio 07: Deixar os graficos bonitoes. (Matplotlib).

fig,ax= plt.subplots()
fig.patch.set_facecolor("#BED7D8")

x = ['24','48','72']
colors=['#E151AF','#2BB8B3','#FED43F']
ax.bar(x,dados['tempo'].value_counts().sort_index(),width=0.8,color=colors)
ax.set_title("Tempo Experimentos",fontsize=15,color='white')
plt.xlabel("Quantidade horas")
plt.ylabel("Num Experimentos")
# Out:
# Text(0, 0.5, 'Num Experimentos')

# %% [markdown]
# # **AULA 02**
#
# ---

# %% [markdown]
# ###Desafios Aula 02:
#
#
#
# 1.   Ordenar o gráfico countplot
# 2.   Melhorar a parte visualizacao alterando tamanho da fonte
# 3.   Plotar os histogramas con seaborn
# 4.   Estudar sobre as estatisticas retornadas no .describe()
# 5.   Refletir sobre a manipulacao dos tamanhos das visualizacoes
# 6.   Fazer outras analises com o boxplot e até com o histograma
# 7.   Resumo

# %%
#diccionario
mapa = {'droga':'composto'}
dados.rename(columns=mapa, inplace=True) #Reemplaza en el dataset original

dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
cod_compostos = dados['composto'].value_counts().index[0:5] #primeiros 5 elementos (index)
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
#dados.query('composto == cod_compostos') #da erro
dados.query('composto in @cod_compostos') #@ esta declarado anteriomente / in é igual ==
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as ply

plt.figure(figsize=(8,6)) #Tamanho da imagem
sns.set() #visual seaborn
ax = sns.countplot(x = 'composto',data=dados.query('composto in @cod_compostos'),palette='winter')
ax.set_title('Top 5 Compostos')
plt.show()

# %%
#DESAFIO 01 e 02

import seaborn as sns
import matplotlib.pyplot as ply

plt.figure(figsize=(8,6)) #Tamanho da imagem
sns.set() #visual seaborn

ax = sns.countplot(x = 'composto',data=dados.query('composto in @cod_compostos'),order=cod_compostos,palette="rocket")

ax.set_title('Top 5 Compostos', fontsize=20)
ax.set_xlabel('Composto', fontsize=15)
ax.set_ylabel('Quantidade', fontsize=15)
plt.show()

# %%
len(dados['g0'].unique())
# Out:
# 14367

# %%
dados['g0'].min()
# Out:
# -5.513

# %%
dados['g0'].max()
# Out:
# 10.0

# %%
dados['g0'].hist(bins=100)

# %%
dados['g10'].hist(bins=100)

# %%
dados['g0'].mean()
# Out:
# 0.24836629293692816

# %%
dados.describe()
# Out:
#               tempo            g0  ...           c98           c99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados[['g0','g1']]
# Out:
#            g0      g1
# 0      1.0620  0.5577
# 1      0.0743  0.4087
# 2      0.6280  0.5817
# 3     -0.5138 -0.2491
# 4     -0.3254 -0.4009
# ...       ...     ...
# 23809  0.1394 -0.0636
# 23810 -1.3260  0.3478
# 23811  0.3942  0.3756
# 23812  0.6660  0.2324
# 23813 -0.8598  1.0240
#
# [23814 rows x 2 columns]

# %%
dados.loc[0:,'g0'].describe()
# Out:
# count    23814.000000
# mean         0.248366
# std          1.393399
# min         -5.513000
# 25%         -0.473075
# 50%         -0.008850
# 75%          0.525700
# max         10.000000
# Name: g0, dtype: float64

# %%
dados.loc[:,'g0':'g711'].describe()
# Out:
#                  g0            g1  ...          g710          g711
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...      0.153914      0.049409
# std        1.393399      0.812363  ...      1.001524      1.487562
# min       -5.513000     -5.737000  ...     -6.876000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.408100     -0.560575
# 50%       -0.008850     -0.046600  ...      0.018950     -0.035650
# 75%        0.525700      0.403075  ...      0.507875      0.501800
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 712 columns]

# %%
dados.loc[:,'g0':'g711'].describe().T.hist(bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f05c104e990>,
# ...
#       dtype=object)

# %%
dados.loc[:,'g0':'g711'].describe().T['mean'].hist(bins=50)

# %%
dados.loc[:,'g0':'g711'].describe().T['min'].hist(bins=50)

# %%
dados.loc[:,'g0':'g711'].describe().T['max'].hist(bins=50)

# %%
dados.loc[:,'c0':'c99'].describe().T['mean'].hist(bins=50)

# %%
sns.boxplot(x='g0' ,data=dados)

# %%
sns.boxplot(x='g0', y='tratamento',data=dados)

# %%
#DESAFIO 03

fig, ax = plt.subplots(1,3, figsize = ( 20 , 5 ))
dados.loc[:,'c0':'c99'].describe().T['mean'].hist(bins=50,ax=ax[0],color ='#1E73BE', histtype='stepfilled').set_title("Média dos tipos celulares")
dados.loc[:,'c0':'c99'].describe().T['min'].hist(bins=50,ax=ax[1],color ='#C850B0',histtype='bar').set_title("Mínimo dos tipos celulares")
dados.loc[:,'c0':'c99'].describe().T['max'].hist(bins=50,ax=ax[2],color ='#660A60',histtype='step').set_title("Máximo dos tipos celulares")
fig.suptitle('Histogramas dos tipos celulares', fontsize=20, color="#000C66")

fig.show()

# %% [markdown]
# ###Desafio 04
#
# Describe()
#
# O método descreve as informações estatísticas de retorno dos dados do dataframe ou dados em série (de fato, este método retorna um dataframe). Esta informação inclui o número de amostras, o valor médio, o desvio padrão, o valor mínimo, o valor máximo, a mediana e os valores correspondentes aos percentis de 25% e 75%.

# %%
#Desafio 06

fig, ax = plt.subplots(3, 3, figsize=(20,10), sharex=True, sharey=True) 


sns.histplot(dados['c0'], ax=ax[0,0],bins=100,color='#FFCA72', element="poly")
sns.histplot(dados['c10'], ax=ax[0,1],bins=100,color='#FF4500', kde=True, element="step")
sns.histplot(dados['c20'], ax=ax[0,2],bins=100,color='#DAD870', kde=True)
sns.histplot(dados['c30'], ax=ax[1,0],bins=100,color='#FF9636', kde=True, fill=False)
sns.histplot(dados['c40'], ax=ax[1,1],bins=100,color='#AE388B',kde=True)
sns.histplot(dados['c50'], ax=ax[1,2],bins=100,color='#FF5C4D', kde=True)
sns.histplot(dados['c60'], ax=ax[2,0],bins=100,color='#B8390E', kde=True)
sns.histplot(dados['c70'], ax=ax[2,1],bins=100,color='#DC4731', kde=True)
sns.histplot(dados['c80'], ax=ax[2,2],bins=100,color='#FB6090')

fig.suptitle('Distribuição de 9 Variáveis Com Prefixo c', fontsize=20, color='#2AB67B')    

plt.show()

# %%
#Desafio 06

plt.figure(figsize=(10,8))
ax = sns.boxplot(y='g0', x='tratamento', hue='dose', data=dados, palette="husl")
ax.set_title('Valores de g0 - com droga e com controle', fontsize = 20, color='#2AB67B')
ax.set_xlabel('Tratamento', fontsize = 15)
ax.set_ylabel('Valores', fontsize = 15)
plt.show()

# %% [markdown]
# ###Desafio 7

# %% [markdown]
# #Aula 03
# ###Correlações, causalidade e relações entre genes.

# %% [markdown]
# ###DESAFIOS AULA 03
#
# 1. Criar tabelas de frecuencia com o `pd.groupby()`.
# 2. Normalizar o crosstab pela coluna.
# 3. Explorar outros agregadores
# 4. Explorar o `melt()`
# 5. Calcular e analizar a correlacao entre G e C. Refletir sobre os efeitos biologicos
# 6. Estudar o codigo que plota a matriz de correlacao (heatmap)

# %%
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'],normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
#DESAFIO 01
dados.groupby(by=['dose','tempo'])['tratamento'].value_counts()
# Out:
# dose  tempo  tratamento
# D1    24     com_droga       3585
#              com_controle     301
#       48     com_droga       4011
#              com_controle     343
#       72     com_droga       3600
#              com_controle     307
# D2    24     com_droga       3581
#              com_controle     305
#       48     com_droga       3591
#              com_controle     305
#       72     com_droga       3580
#              com_controle     305
# Name: tratamento, dtype: int64

# %%
#DESAFIO 01
dados.groupby(by=['dose','tempo'])['tratamento'].value_counts(normalize=True)
# Out:
# dose  tempo  tratamento
# D1    24     com_droga       0.922542
#              com_controle    0.077458
#       48     com_droga       0.921222
#              com_controle    0.078778
#       72     com_droga       0.921423
#              com_controle    0.078577
# D2    24     com_droga       0.921513
#              com_controle    0.078487
#       48     com_droga       0.921715
#              com_controle    0.078285
#       72     com_droga       0.921493
#              com_controle    0.078507
# Name: tratamento, dtype: float64

# %%
#DESAFIO 02
#Normaliza pela coluna
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'],normalize=1)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %%
#DESAFIO 03
#Maximo
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc='max')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24            3.226      9.908
#      48            3.423     10.000
#      72            2.584      9.355
# D2   24            2.601      7.167
#      48            4.335     10.000
#      72            4.670     10.000

# %%
#DESAFIO 03
#Maximo
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc='min')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24           -2.370     -5.183
#      48           -3.276     -5.420
#      72           -2.086     -5.261
# D2   24           -2.135     -5.233
#      48           -4.859     -4.567
#      72           -1.909     -5.513

# %%
#DESAFIO 03
#Minimo
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc=min)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24           -2.370     -5.183
#      48           -3.276     -5.420
#      72           -2.086     -5.261
# D2   24           -2.135     -5.233
#      48           -4.859     -4.567
#      72           -1.909     -5.513

# %%
#DESAFIO 03
#Soma
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc=sum, margins=True)
# Out:
# tratamento  com_controle  com_droga        All
# dose tempo
# D1   24         -75.7799  1319.2648  1243.4849
#      48         -42.1113  1654.4150  1612.3037
#      72         -90.6483  1030.5010   939.8527
# D2   24           3.2800   412.7202   416.0002
#      48           4.0180   770.1980   774.2160
#      72          21.4262   907.3112   928.7374
# All            -179.8153  6094.4102  5914.5949

# %%
#DESAFIO 04
pd.melt(dados, id_vars=["tratamento","dose"], value_vars=["tempo"]).value_counts().sort_values()
# Out:
# tratamento    dose  variable  value
# com_controle  D1    tempo     24        301
#               D2    tempo     72        305
#                               48        305
#                               24        305
#               D1    tempo     72        307
#                               48        343
# com_droga     D2    tempo     72       3580
#                               24       3581
#               D1    tempo     24       3585
#               D2    tempo     48       3591
#               D1    tempo     72       3600
#                               48       4011
# dtype: int64

# %%
dados[['g0','g3']]
# Out:
#            g0      g3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
sns.scatterplot(x='g0', y='g3', data=dados)

# %%
sns.scatterplot(x='g0', y='g8', data=dados)

# %%
sns.lmplot(data=dados, x='g0', y='g8', line_kws={'color':'red'})

# %%
sns.lmplot(data=dados, x='g0', y='g8', line_kws={'color':'red'}, col='tratamento')

# %%
sns.lmplot(data=dados, x='g0', y='g8', line_kws={'color':'red'}, col='tratamento', row='tempo')

# %%
dados.loc[:,'g0':'g711'].corr()
# Out:
#             g0        g1        g2  ...      g709      g710      g711
# g0    1.000000  0.086032  0.176188  ... -0.227691  0.426917  0.269032
# g1    0.086032  1.000000 -0.054518  ...  0.023665 -0.070588  0.023646
# g2    0.176188 -0.054518  1.000000  ... -0.083571  0.092079  0.116229
# g3    0.011266 -0.027855  0.042633  ... -0.088272 -0.020720  0.197289
# g4    0.403153  0.193647  0.013968  ... -0.059669  0.188710  0.130505
# ...        ...       ...       ...  ...       ...       ...       ...
# g707  0.011391 -0.002208  0.002540  ... -0.033378 -0.002302 -0.003678
# g708  0.381758  0.001169  0.123948  ... -0.215672  0.197536  0.510416
# g709 -0.227691  0.023665 -0.083571  ...  1.000000 -0.158232 -0.314455
# g710  0.426917 -0.070588  0.092079  ... -0.158232  1.000000  0.095093
# g711  0.269032  0.023646  0.116229  ... -0.314455  0.095093  1.000000
#
# [712 rows x 712 columns]

# %%
import numpy as np

# Compute the correlation matrix
corr = dados.loc[:,'g0':'g50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
#cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap="rocket", center=0, 
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# Compute the correlation matrix
corr_cel = dados.loc[:,'c0':'c50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_cel, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_cel, mask=mask, cmap=cmap, center=0, 
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
#DESAFIO 05

gs = dados[dados['tratamento']  == 'com_droga'].loc[:,'g0':'g50']
cs = dados[dados['tratamento']  == 'com_droga'].loc[:,'c0':'c50']
dados_filtrados = pd.concat([gs,cs],axis=1)
dados_filtrados

corr_05 = dados_filtrados.corr().round(2)
corr_filtrada = corr_05.loc[:'g50','c0':]

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_filtrada, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
#cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_filtrada,  cmap='viridis', center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})


#No grafico podemos ver a relação de expressão de que cada gene segue a "mesma" correlação com todas as viabilidade celular das celulas.

# %% [markdown]
# ####Desafio 06
#
# https://seaborn.pydata.org/generated/seaborn.heatmap.html#seaborn.heatmap

# %% [markdown]
# #Aula 04
# MERGE DE DADOS E ANÁLISE DE RESULTADOS

# %% [markdown]
# ###DESAFIOS AULA 04
#
# 1. Encontrar o top 10 das acoes do MOA (inibidor, agonista, ...)
# 2. Criar a coluna eh_controle para quando na lina tratamento == com_controle
# 3. Criar tres colunas e indicar o tempo 24, 48, 72
# 4. Estudar sobre as combinacoes de DF
# 5. Fazer analise mas detalhado considerando tempo e dose, para comparar as distribucoes
# 6. Descobrir se temos algum composto que dependendo da configuracao do experimento ativa ou nao ativa algum MOA (ou um MOA diferente)
# 7. Descobrir se temos algum composto que dependendo da configuracao do experimento ativa MOA's diferentes
# 8. Resumo

# %%
dados_resultados = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/imersao-dados-desafio-final/main/Dados/dados_resultados.csv")
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados['acat_inhibitor'].unique()
# Out:
# array([0, 1])

# %%
dados_resultados['acetylcholine_receptor_agonist'].unique()

#1 O mecanismo de ação foi ativado
#0 O mecanismo de ação não foi ativado
# Out:
# array([0, 1])

# %%
contagem_moa = dados_resultados.select_dtypes('int64').sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
#outra forma de análise - igual resultado
contagem_moa1 = dados_resultados.drop(columns='id').sum().sort_values(ascending=False)
contagem_moa1
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dados_resultados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 207 entries, id to wnt_inhibitor
# dtypes: int64(206), object(1)
# memory usage: 37.6+ MB

# %%
#Desafio 01 
#https://pandas.pydata.org/docs/reference/api/pandas.Series.str.split.html
#[-1] selecione a última palavra depois do '_'
novos_indices = [i.split('_')[-1] for i in contagem_moa.index ]
novos_indices[:10]
# Out:
# ['inhibitor',
#  'inhibitor',
#  'inhibitor',
#  'antagonist',
#  'antagonist',
#  'inhibitor',
#  'antagonist',
#  'antagonist',
#  'inhibitor',
#  'inhibitor']

# %%
ser_moa = pd.Series(data=contagem_moa.values, index=novos_indices)
top10 = ser_moa.groupby(level=0).sum().sort_values(ascending=False).head(10)
top10
# Out:
# inhibitor            9693
# antagonist           3449
# agonist              2330
# blocker               323
# agent                 150
# activator             115
# local                  80
# immunosuppressant      73
# anti-inflammatory      73
# antioxidant            73
# dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10, 5))
# creating the bar plot
plt.barh(top10.index, top10.values, color='#FAD02C')
  
plt.xlabel("Contagem", fontsize=12,fontweight='bold', color='#333652')
plt.ylabel("ação", fontsize=12,fontweight='bold', color='#333652')
plt.title("Top 10 ação", fontsize=15,loc='left',fontweight='bold', color='#333652')
ax.invert_yaxis()

#Change background to ax and fig
fig.patch.set_facecolor('#90ADC6')
ax.set_facecolor('#E9EAEC')

# Add x, y gridlines
ax.grid(b=True, color='black',
        linestyle='-.', linewidth=0.5,
        alpha=0.2)

# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize=10, 
             color='#333652')
    
plt.show()

# %%
dados_resultados.drop(columns='id').sum(axis=1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados['n_moa'] = dados_resultados.drop(columns='id').sum(axis=1)

# %%
dados_resultados['n_moa'] != 0
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 23809     True
# 23810     True
# 23811    False
# 23812     True
# 23813    False
# Name: n_moa, Length: 23814, dtype: bool

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] != 0 )
#del(dados_resultados['n_moa'])
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
dados_combinados = pd.merge(dados, dados_resultados[['id','n_moa','ativo_moa']], on='id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...     c98     c99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
dados_combinados.query('tratamento == "com_controle" ').head()
# Out:
#               id    tratamento  tempo dose  ...     c98     c99  n_moa  ativo_moa
# 25  id_0054388ec  com_controle     48   D1  ...  0.8976  1.0050      0      False
# 38  id_0079af0fb  com_controle     24   D1  ...  0.6498 -1.4820      0      False
# 40  id_007bfbb91  com_controle     24   D2  ...  0.8543  0.9180      0      False
# 47  id_008a986b7  com_controle     48   D2  ... -0.9245 -0.9367      0      False
# 63  id_009d8340f  com_controle     24   D2  ... -0.4326  0.9364      0      False
#
# [5 rows x 879 columns]

# %%
dados_combinados.query('tratamento == "com_controle" ')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
#DESAFIO 02

eh_controle = dados_combinados['tratamento'] == 'com_controle'
dados_combinados['eh_controle'] = eh_controle.astype('int')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...     c99  n_moa  ativo_moa  eh_controle
# 0  id_000644bb2  com_droga     24   D1  ...  0.4176      1       True            0
# 1  id_000779bfc  com_droga     72   D1  ...  0.7371      0      False            0
# 2  id_000a6266a  com_droga     48   D1  ...  0.6931      3       True            0
# 3  id_0015fd391  com_droga     48   D1  ... -0.8154      0      False            0
# 4  id_001626bd3  com_droga     72   D2  ...  0.7125      1       True            0
#
# [5 rows x 880 columns]

# %%
#DESAFIO 03

time_24 = dados_combinados['tempo'] == 24
time_48 = dados_combinados['tempo'] == 48
time_72 = dados_combinados['tempo'] == 72

# %%
dados_combinados['tempo_24'],dados_combinados['tempo_48'], dados_combinados['tempo_72'] = [time_24,time_48,time_72]
dados_combinados.head(10)
# Out:
#              id tratamento  tempo  ... tempo_24 tempo_48  tempo_72
# 0  id_000644bb2  com_droga     24  ...     True    False     False
# 1  id_000779bfc  com_droga     72  ...    False    False      True
# 2  id_000a6266a  com_droga     48  ...    False     True     False
# 3  id_0015fd391  com_droga     48  ...    False     True     False
# 4  id_001626bd3  com_droga     72  ...    False    False      True
# 5  id_001762a82  com_droga     24  ...     True    False     False
# 6  id_001bd861f  com_droga     24  ...     True    False     False
# 7  id_0020d0484  com_droga     48  ...    False     True     False
# 8  id_00224bf20  com_droga     48  ...    False     True     False
# 9  id_0023f063e  com_droga     48  ...    False     True     False
#
# [10 rows x 883 columns]

# %% [markdown]
# ####DESAFIO 04
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %%
dados_combinados.query('tratamento == "com_droga" ')['ativo_moa'].value_counts(normalize=True)
# Out:
# True     0.658238
# False    0.341762
# Name: ativo_moa, dtype: float64

# %%
compostos_principal = dados_combinados['composto'].value_counts().index[:5]
#compostos_principal
plt.figure(figsize=(15,8))
sns.boxplot(data=dados_combinados.query('composto in @compostos_principal'), x ='composto', y='g0', hue='ativo_moa')

# %%
#DESAFIO 05 
df_composto1 = dados_combinados[dados_combinados['composto']=='8b87a7a83'] #Droga cacb2b860
df_composto2 = dados_combinados[dados_combinados['composto']=='87d714366'] #Droga
df_controle = dados_combinados[dados_combinados['tratamento']=='com_controle'] 

#df_controle.query('tratamento == "com_controle" ')['composto'].value_counts().sort_values()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=df_composto1, x ='tempo', y='g0', hue='dose', palette='flare')

# %%
plt.figure(figsize=(8,6))
sns.catplot(x='tempo', y='g100', data=df_composto2, kind='boxen', hue='dose', palette='husl')

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=df_controle, x ='tempo', y='g0', hue='dose', palette='rocket')

# %%
plt.figure(figsize=(8,6))
sns.catplot(x='tempo', y='g100', data=df_controle, kind='violin', hue='dose', palette='viridis')

# %%
sns.dogplot()

# %%
#DESAFiO 06
#filtro composto pelo ativo
ativos_moa = (dados_combinados['composto'].value_counts() == 1).astype(int)
ativos_moa_true = ativos_moa[ativos_moa !=0 ]
ativos_moa_true
# Out:
# 288e0d205    1
# 32dccc366    1
# b472193a9    1
# 58d311643    1
# 379302187    1
#             ..
# e3fe7b417    1
# 6e418401d    1
# 809527b9d    1
# 627d2d158    1
# dd4a96d16    1
# Name: composto, Length: 129, dtype: int64

# %%
print(range(len(ativos_moa_true)))
# Out:
# range(0, 129)

# %%
cont = 0

for i in range(len(ativos_moa_true)): 
  if ativos_moa_true[i] == 1:
    pass
  else:
    cont = cont+1

if cont == 0:
  print("Todos os compostos têm apenas um tipo de ativação")
else:
  pass
# Out:
# Todos os compostos têm apenas um tipo de ativação

# %%
#DESAFIO 07
selecao_moa2_nunique = dados_combinados.groupby(by='composto')['n_moa'].nunique()
selecao_moa2_nunique
# Out:
# composto
# 00199ff52    1
# 00251fc41    1
# 00321ea80    1
# 0034c0847    1
# 0060e686f    1
#             ..
# ff9565933    1
# ffd66e220    1
# ffe357f8f    1
# ffed8e1c9    1
# fff7d208d    1
# Name: n_moa, Length: 3289, dtype: int64

# %%
cont = 0
for i in range(len(selecao_moa2_nunique)):
  if selecao_moa2_nunique[i] == 1:
    pass
  else:
    cont = cont+ 1
    print(selecao_moa2_nunique[i].index)

if cont == 0:
  print('nenhum MOA diferente foi ativado dependendo das condições')
else:
  pass
# Out:
# nenhum MOA diferente foi ativado dependendo das condições
